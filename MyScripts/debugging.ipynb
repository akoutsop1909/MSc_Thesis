# %%
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import cv2
import os

# %%
os.chdir('D:\\Informatics\\Μεταπτυχιακό\\Εξάμηνο Γ\\dataset')
depth = np.load('gt2.npy')
depth = np.reshape(depth, (192, 256))
df = pd.DataFrame(depth)
df.to_csv('ground_truth.csv', index=False)
plt.imshow(depth, interpolation='nearest')
plt.show()
print(depth)
# Out:
# [[0.1328125  0.13671875 0.14453125 ... 0.03125    0.02734375 0.02734375]
#  [0.125      0.1328125  0.14453125 ... 0.02734375 0.03125    0.02734375]
#  [0.07421875 0.12890625 0.13671875 ... 0.03125    0.03125    0.03125   ]
#  ...
#  [0.0078125  0.0078125  0.0078125  ... 0.0078125  0.0078125  0.0078125 ]
#  [0.0078125  0.0078125  0.0078125  ... 0.0078125  0.0078125  0.0078125 ]
#  [0.0078125  0.0078125  0.0078125  ... 0.0078125  0.0078125  0.0078125 ]]

# %%
os.chdir('D:\\Informatics\\Μεταπτυχιακό\\Εξάμηνο Γ\\dataset')
depth = np.load('pred2.npy')
depth = np.reshape(depth, (192, 256))
df = pd.DataFrame(depth)
df.to_csv('prediction.csv', index=False)
plt.imshow(depth, interpolation='nearest')
plt.show()
print(depth)
# Out:
# [[ 9.538004   9.803963  10.354327  ... 19.100155  35.444214  44.710125 ]
#  [ 8.792705   9.0993     9.7404995 ... 21.184914  28.784225  35.11276  ]
#  [ 7.4542046  7.8220663  8.606594  ... 25.862297  17.525568  14.186724 ]
#  ...
#  [ 6.917308   6.308952   5.236848  ...  1.4801028  1.481518   1.4841669]
#  [11.806568   7.807445   6.308951  ...  1.4815158  1.4833767  1.4843199]
#  [ 9.690735   8.780677   6.917306  ...  1.4822233  1.4880091  1.5476401]]

# %%
os.chdir('D:\\Informatics\\Μεταπτυχιακό\\Εξάμηνο Γ\\dataset')
depth2 = np.load('00022_00193_outdoor_010_010_depth.npy')
df2 = pd.DataFrame(depth2.flatten())
df2.to_csv('diode.csv', index=False)
print(depth2)
# Out:
# [[22.272635  26.052702  27.984318  ... 21.539366  21.326555  20.15863  ]
#  [24.419334  27.076971  27.282372  ... 19.372187  21.013992  26.526127 ]
#  [26.323584  26.04801   26.067099  ... 18.872566  22.23554   26.409317 ]
#  ...
#  [ 4.0009212  4.0931735  4.205983  ...  5.8635426  5.4930882  5.573932 ]
#  [ 4.0390177  3.9046001  4.220045  ...  5.4787183  5.523669   5.1552615]
#  [ 3.870092   3.9270406  4.2339745 ...  5.648932   5.324764   6.2439485]]

# %%
depth2 = np.reshape(depth2, (192, 256))
