# %%
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import cv2
import os

# %%
os.chdir('D:\\Informatics\\Μεταπτυχιακό\\Εξάμηνο Γ\\dataset')
depth = np.load('gt.npy')
depth = np.squeeze(depth)
#depth = np.resize(depth, (192,256))
depth = np.reshape(depth, (192, 256))
#df = pd.DataFrame(depth)
#df.to_csv('ground_truth.csv', index=False)
plt.imshow(depth, interpolation='nearest')
plt.show()
#print(depth)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 5
#       3 depth = np.squeeze(depth)
#       4 #depth = np.resize(depth, (192,256))
# ----> 5 depth = np.reshape(depth, (256, 192))
#       6 #df = pd.DataFrame(depth)
#       7 #df.to_csv('ground_truth.csv', index=False)
#       8 plt.imshow(depth, interpolation='nearest')
#
# File ~\Documents\GitHub\MSc_Thesis\venv\lib\site-packages\numpy\core\fromnumeric.py:285, in reshape(a, newshape, order)
#     200 @array_function_dispatch(_reshape_dispatcher)
#     201 def reshape(a, newshape, order='C'):
#     202     """
#     203     Gives a new shape to an array without changing its data.
#     204
#    (...)
#     283            [5, 6]])
#     284     """
# --> 285     return _wrapfunc(a, 'reshape', newshape, order=order)
#
# File ~\Documents\GitHub\MSc_Thesis\venv\lib\site-packages\numpy\core\fromnumeric.py:59, in _wrapfunc(obj, method, *args, **kwds)
#      56     return _wrapit(obj, method, *args, **kwds)
#      58 try:
# ---> 59     return bound(*args, **kwds)
#      60 except TypeError:
#      61     # A TypeError occurs if the object does have such a method in its
#      62     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      66     # Call _wrapit from within the except clause to ensure a potential
#      67     # exception has a traceback chain.
#      68     return _wrapit(obj, method, *args, **kwds)
#
# ValueError: cannot reshape array of size 786432 into shape (256,192)

# %%
os.chdir('D:\\Informatics\\Μεταπτυχιακό\\Εξάμηνο Γ\\dataset')
depth = np.load('pred6.npy')
depth = np.reshape(depth, (144, 192))
#df = pd.DataFrame(depth)
#df.to_csv('prediction.csv', index=False)
plt.imshow(depth, interpolation='nearest')
plt.show()
#print(depth)

# %%
os.chdir('D:\\Informatics\\Μεταπτυχιακό\\Εξάμηνο Γ\\dataset')
depth2 = np.load('00022_00193_outdoor_010_010_depth.npy')
df2 = pd.DataFrame(depth2.flatten())
df2.to_csv('diode.csv', index=False)
print(depth2)
# Out:
# [[22.272635  26.052702  27.984318  ... 21.539366  21.326555  20.15863  ]
#  [24.419334  27.076971  27.282372  ... 19.372187  21.013992  26.526127 ]
#  [26.323584  26.04801   26.067099  ... 18.872566  22.23554   26.409317 ]
#  ...
#  [ 4.0009212  4.0931735  4.205983  ...  5.8635426  5.4930882  5.573932 ]
#  [ 4.0390177  3.9046001  4.220045  ...  5.4787183  5.523669   5.1552615]
#  [ 3.870092   3.9270406  4.2339745 ...  5.648932   5.324764   6.2439485]]

# %%
depth2 = np.reshape(depth2, (192, 256))
